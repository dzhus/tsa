-- %%
{-# LANGUAGE FlexibleContexts #-}

import TSA

import qualified Data.Vector.Unboxed as V

import IHaskell.Display.Charts

-- %%
--let series = V.fromList $ Prelude.take 100 $ map (\x -> (x / 2) + sin x + cos (x / 2)) [(1 :: Double)..]
series <- loadSeries "/Users/dmitrydzhus/Downloads/DEXUSEU.csv" 1

-- %%
TSA.plotACF 20 $ diff 1 series

-- %%
TSA.plotPredictions 5 mean $ diff 1 series

-- %%
TSA.plotPredictions 5 linearTrend $ diff 1 series

-- %%
TSA.plotResiduals mean $ diff 1 series
