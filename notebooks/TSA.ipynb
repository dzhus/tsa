-- %%
{-# LANGUAGE FlexibleContexts #-}

import TSA

import qualified Data.Vector.Unboxed as V

import IHaskell.Display.Charts

-- %%
let series = V.fromList $ Prelude.take 30 $ map (\x -> (x / 2) + sin x + cos (x / 2)) [(1 :: Double)..]

TSA.plotPredictions 5 mean series

-- %%
TSA.plotPredictions 5 linearTrend series
